# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('../data/hmeq_clean.csv')
data.drop(columns=['Unnamed: 0'],inplace=True)

# %%
data_cat = pd.read_csv('../data/hmeq_clean_cat.csv')
data_cat.drop(columns=['Unnamed: 0'],inplace=True)

# %%
y = data['BAD']

# %% [markdown]
# If there are any highly correlated columns I would like to delete the feature, but there are not any

# %%
correlation_matrix = data.corr()
plt.figure(figsize=(10,10))
sns.heatmap(correlation_matrix, annot=True);

# %%
from sklearn.preprocessing import StandardScaler, Normalizer
from sklearn.pipeline import make_pipeline

pipeline = [
    StandardScaler(),
    Normalizer(),
]

def pipelinise(df):
    X = df.drop(columns=['BAD']) #FEATURE VECTOR
    tr = make_pipeline(*pipeline)
    Xpr = tr.fit_transform(X)
    return pd.DataFrame(Xpr,columns=X.columns)
data_norm = pipelinise(data)
data_norm_cat = pipelinise(data_cat)
# Out:
# /Users/luciasuelves/opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Users/luciasuelves/opt/anaconda3/lib/python3.7/site-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /Users/luciasuelves/opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Users/luciasuelves/opt/anaconda3/lib/python3.7/site-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
from sklearn.model_selection import train_test_split

def split(df):
    Xpr = pipelinise(df)
    return train_test_split(Xpr,y , test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LogisticRegression

def log_reg(df):
    X_train,X_test,y_train,y_test = split(df)
    model = LogisticRegression(solver="lbfgs")
    model.fit(X_train, y_train)
    return (model,X_test,y_test)

# %%
result = pd.DataFrame({
    "y_pred":y_pred,
    "gt":y_test
})

# %%
# %matplotlib inline
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

def scoring(df):
    y_personalised = []
    neg = 0
    pos = 0
    model,X_test,y_test = log_reg(df)
    y_pred = model.predict(X_test)
    y_score = model.predict_proba(X_test)
     
    for i in range(len(y_score)):
        if y_score[:,1][i] > 0.4:
            y_personalised.append(1)
        else:
            y_personalised.append(0)
            
    roc = roc_curve(y_test, y_personalised)        
    #roc = roc_curve(y_test, y_score[:,1])
    display(pd.DataFrame({
        "predicted":y_pred,
        "personalised": y_personalised,
        "gt": y_test,
        "probaNotPay":y_score[:,1],
        "probaPay":y_score[:,0]
        }).head())

    plt.plot(roc[0],roc[1])
    plt.legend([f"AUC: {round(roc_auc_score(y_test, y_score[:,1]),2)}"])
    #model.predict_proba(X_test)[0]
    result = pd.DataFrame({
    "y_pred":y_pred,
    "gt":y_test
                })


    for i in range(len(y_pred)):
        if y_personalised[i] < y_test.values[i]:
            neg += 1
        elif y_personalised[i] > y_test.values[i]:
            pos += 1
            
    return (1-np.abs(y_personalised-y_test).sum()/len(y_test),1-np.abs(y_pred-y_test).sum()/len(y_test), neg/(pos+neg))

# %%
scoring(data)
# Hay mas errores de dar un loan a alguien que luego no paga. 
# Podemos hacer que la probabilidad que necesita a su favor sea más alta.
# Out:
# /Users/luciasuelves/opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Users/luciasuelves/opt/anaconda3/lib/python3.7/site-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
#       predicted  personalised  gt  probaNotPay  probaPay
# 5048          0             0   0     0.161153  0.838847
# 3563          0             0   0     0.066661  0.933339
# 5343          0             0   0     0.366079  0.633921
# 168           0             0   0     0.292704  0.707296
# 3051          0             0   0     0.024450  0.975550
# (0.8431208053691275, 0.8498322147651007, 0.5721925133689839)

# %%
scoring(data_cat)
# Out:
# /Users/luciasuelves/opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Users/luciasuelves/opt/anaconda3/lib/python3.7/site-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
#       predicted  personalised  gt  probaNotPay  probaPay
# 5048          0             0   0     0.173905  0.826095
# 3563          0             0   0     0.058658  0.941342
# 5343          0             1   0     0.426365  0.573635
# 168           0             0   0     0.297211  0.702789
# 3051          0             0   0     0.021763  0.978237
# (0.8431208053691275, 0.8422818791946309, 0.5508021390374331)

# %%
data_norm['BAD'] = y
scoring(data_norm)
# Out:
#       predicted  personalised  gt  probaNotPay  probaPay
# 5048          0             0   0     0.157843  0.842157
# 3563          0             0   0     0.060011  0.939989
# 5343          0             0   0     0.339914  0.660086
# 168           0             0   0     0.292699  0.707301
# 3051          0             0   0     0.021651  0.978349
# (0.8431208053691275, 0.848993288590604, 0.5668449197860963)

# %%
data_norm_cat['BAD'] = y
scoring(data_norm_cat)
# Out:
#       predicted  personalised  gt  probaNotPay  probaPay
# 5048          0             0   0     0.170471  0.829529
# 3563          0             0   0     0.056442  0.943558
# 5343          0             0   0     0.388049  0.611951
# 168           0             0   0     0.292350  0.707650
# 3051          0             0   0     0.019860  0.980140
# (0.8380872483221476, 0.8498322147651007, 0.5284974093264249)

# %% [markdown]
# In the causalnex model, I need to select a limited number of features, so to choose them I could use the following

# %%
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest

X = data_cat.drop(columns=['BAD'])
featurer = SelectKBest(chi2, k=5)
X_new = featurer.fit_transform(np.abs(X), y)

# %%
print(X.columns[featurer.get_support()])
# Out:
# Index(['LOAN', 'MORTDUE', 'VALUE', 'CLAGE', 'DEBTINC'], dtype='object')

# %%
data_reduced = X[X.columns[featurer.get_support()]]
data_reduced['BAD'] = y
scoring(data_reduced)
# Out:
# /Users/luciasuelves/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/luciasuelves/opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Users/luciasuelves/opt/anaconda3/lib/python3.7/site-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
#       predicted  personalised  gt  probaNotPay  probaPay
# 5048          0             0   0     0.348573  0.651427
# 3563          0             0   0     0.048171  0.951829
# 5343          0             0   0     0.464380  0.535620
# 168           0             0   0     0.439794  0.560206
# 3051          0             0   0     0.093290  0.906710
# (0.8271812080536913, 0.8271812080536913, 0.7087378640776699)

# %% [markdown]
# Its worse

# %% [markdown]
# What's worse? To give the loan and not pay or to not give the loan and pay? I have to change the percentages.

# %%
#I don't know

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def train(df):
    X_train,X_test,y_train,y_test = split(df)
    models = {
        "logis": LogisticRegression(C=10,solver="lbfgs"),
        "svm-linear": CalibratedClassifierCV(LinearSVC(),cv=3),
        "svm-rbf": CalibratedClassifierCV(SVC(kernel="sigmoid",gamma="auto"),cv=3),
        "randomforest": RandomForestClassifier(n_estimators=200),
    }

# Train all the models in the models dict
    for name,m  in models.items():
        print(f"Training {name}...")
        m.fit(X_train, y_train)
    print("Train complete")
    

    printMetric = lambda label,value:print(f"\t {label}: {round(value,3)}")

    for name, model in models.items():
        y_pred = model.predict(X_test)
        print(f"Evaluating model {name}")
        printMetric("Accuracy",accuracy_score(y_test, y_pred))
        printMetric("Precision",precision_score(y_test, y_pred))
        printMetric("Recall",recall_score(y_test, y_pred))
        printMetric("F1Score",f1_score(y_test, y_pred))

    return("Train complete")

# %%
dfs = [data, data_norm, data_cat, data_norm_cat]
[train(df) for df in dfs]
# Out:
# /Users/luciasuelves/opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Users/luciasuelves/opt/anaconda3/lib/python3.7/site-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# Training logis...
# Training svm-linear...
# Training svm-rbf...
# Training randomforest...
# Train complete
# Evaluating model logis
# 	 Accuracy: 0.85
# 	 Precision: 0.667
# 	 Recall: 0.416
# 	 F1Score: 0.512
# Evaluating model svm-linear
# 	 Accuracy: 0.842
# 	 Precision: 0.638
# 	 Recall: 0.389
# 	 F1Score: 0.484
# Evaluating model svm-rbf
# 	 Accuracy: 0.84
# 	 Precision: 0.632
# 	 Recall: 0.372
# 	 F1Score: 0.468
# Evaluating model randomforest
# 	 Accuracy: 0.893
# 	 Precision: 0.78
# 	 Recall: 0.611
# 	 F1Score: 0.685
# Training logis...
# Training svm-linear...
# Training svm-rbf...
# Training randomforest...
# Train complete
# Evaluating model logis
# 	 Accuracy: 0.851
# 	 Precision: 0.667
# 	 Recall: 0.425
# 	 F1Score: 0.519
# Evaluating model svm-linear
# 	 Accuracy: 0.846
# 	 Precision: 0.646
# 	 Recall: 0.412
# 	 F1Score: 0.503
# Evaluating model svm-rbf
# 	 Accuracy: 0.836
# 	 Precision: 0.618
# 	 Recall: 0.358
# 	 F1Score: 0.454
# Evaluating model randomforest
# 	 Accuracy: 0.893
# 	 Precision: 0.786
# 	 Recall: 0.602
# 	 F1Score: 0.682
# Training logis...
# /Users/luciasuelves/opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Users/luciasuelves/opt/anaconda3/lib/python3.7/site-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# Training svm-linear...
# Training svm-rbf...
# Training randomforest...
# Train complete
# Evaluating model logis
# 	 Accuracy: 0.842
# 	 Precision: 0.632
# 	 Recall: 0.403
# 	 F1Score: 0.492
# Evaluating model svm-linear
# 	 Accuracy: 0.839
# 	 Precision: 0.621
# 	 Recall: 0.385
# 	 F1Score: 0.475
# Evaluating model svm-rbf
# 	 Accuracy: 0.84
# 	 Precision: 0.628
# 	 Recall: 0.381
# 	 F1Score: 0.474
# Evaluating model randomforest
# 	 Accuracy: 0.901
# 	 Precision: 0.829
# 	 Recall: 0.602
# 	 F1Score: 0.697
# Training logis...
# Training svm-linear...
# Training svm-rbf...
# Training randomforest...
# Train complete
# Evaluating model logis
# 	 Accuracy: 0.848
# 	 Precision: 0.651
# 	 Recall: 0.429
# 	 F1Score: 0.517
# Evaluating model svm-linear
# 	 Accuracy: 0.841
# 	 Precision: 0.629
# 	 Recall: 0.398
# 	 F1Score: 0.488
# Evaluating model svm-rbf
# 	 Accuracy: 0.844
# 	 Precision: 0.652
# 	 Recall: 0.381
# 	 F1Score: 0.48
# Evaluating model randomforest
# 	 Accuracy: 0.896
# 	 Precision: 0.819
# 	 Recall: 0.58
# 	 F1Score: 0.679
# ['Train complete', 'Train complete', 'Train complete', 'Train complete']
